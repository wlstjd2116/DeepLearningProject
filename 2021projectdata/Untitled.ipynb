# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os 
os.listdir('./dataset_items')
# Out:
# ['201606.csv',
#  '201607.csv',
#  '201608.csv',
#  '201609.csv',
#  '201610.csv',
#  '201611.csv',
#  '201612.csv',
#  '201701.csv',
#  '201702.csv',
#  '201703.csv',
#  '201704.csv',
#  '201705.csv',
#  '201706.csv',
#  '201707.csv',
#  '201708.csv',
#  '201709.csv',
#  '201710.csv',
#  '201711.csv',
#  '201712.csv',
#  '201801.csv',
#  '201802.csv',
#  '201803-01.csv',
#  '201803-02.csv',
#  '201804-01.csv',
#  '201804-02.csv',
#  '201805-01.csv',
#  '201805-02.csv',
#  '201806-01.csv',
#  '201806-02.csv',
#  '201807.csv',
#  '201808-01.csv',
#  '201808-02.csv',
#  '201809.csv',
#  '201810.csv',
#  '201811-01.csv',
#  '201811-02.csv',
#  '201812.csv',
#  '201901.csv',
#  '201902.csv',
#  '201903.csv',
#  '201904.csv',
#  '201905.csv',
#  '201906.csv',
#  '201907.csv',
#  '201908-01.csv',
#  '201908-02.csv',
#  '201909.csv',
#  '201910.csv',
#  '201911-01.csv',
#  '201911-02.csv',
#  '201912.csv',
#  '202001.csv',
#  '202002.csv',
#  '202003.csv',
#  '202004.csv',
#  '202005.csv',
# ...

# %%
forders= os.listdir('./dataset_items')

# %%
cd dataset_items
# Out:
# C:\Users\mo135\2021projectdata\dataset_items

# %%
df_all_years = pd.DataFrame()

# %%
for files in forders:
    df= pd.read_csv(files, encoding='cp949',header=None, low_memory=False)
    df_all_years = pd.concat([df_all_years, df], ignore_index=True)

df_all_years
# Out:
#                        0           1     2              3       4     5    6
# 0                    상품명         조사일  판매가격           판매업소     제조사  세일여부  1+1
# 1              샘표소면(1kg)  2016-06-03  3800        홈플러스감만점      샘표     N    N
# 2              샘표소면(1kg)  2016-06-03  3800        홈플러스천안점      샘표     N    N
# 3              샘표소면(1kg)  2016-06-03  3800        홈플러스목동점      샘표     N    N
# 4              샘표소면(1kg)  2016-06-03  3800        홈플러스구월점      샘표     N    N
# ...                  ...         ...   ...            ...     ...   ...  ...
# 41057065  해피바스 내추럴24핸드크림  2021-05-28  8000        (주)충북유통  아모레퍼시픽     N    N
# 41057066  해피바스 내추럴24핸드크림  2021-05-28  8000         CU(본사)  아모레퍼시픽     N    N
# 41057067  해피바스 내추럴24핸드크림  2021-05-28  8000      세븐일레븐(본사)  아모레퍼시픽     N    N
# 41057068  해피바스 내추럴24핸드크림  2021-05-28  8000      (주)농협대전유통  아모레퍼시픽     N    N
# 41057069  해피바스 내추럴24핸드크림  2021-05-28  8500  (주)부산경남유통 부산점  아모레퍼시픽     N    N
#
# [41057070 rows x 7 columns]

# %%
df_all_years = df_all_years.drop([df_all_years.columns[5], df_all_years.columns[6]], axis=1)

# %%
df_all_years
# Out:
#                        0           1     2              3       4
# 0                    상품명         조사일  판매가격           판매업소     제조사
# 1              샘표소면(1kg)  2016-06-03  3800        홈플러스감만점      샘표
# 2              샘표소면(1kg)  2016-06-03  3800        홈플러스천안점      샘표
# 3              샘표소면(1kg)  2016-06-03  3800        홈플러스목동점      샘표
# 4              샘표소면(1kg)  2016-06-03  3800        홈플러스구월점      샘표
# ...                  ...         ...   ...            ...     ...
# 41057065  해피바스 내추럴24핸드크림  2021-05-28  8000        (주)충북유통  아모레퍼시픽
# 41057066  해피바스 내추럴24핸드크림  2021-05-28  8000         CU(본사)  아모레퍼시픽
# 41057067  해피바스 내추럴24핸드크림  2021-05-28  8000      세븐일레븐(본사)  아모레퍼시픽
# 41057068  해피바스 내추럴24핸드크림  2021-05-28  8000      (주)농협대전유통  아모레퍼시픽
# 41057069  해피바스 내추럴24핸드크림  2021-05-28  8500  (주)부산경남유통 부산점  아모레퍼시픽
#
# [41057070 rows x 5 columns]

# %%
df_all_years = df_all_years.drop([df_all_years.columns[3], df_all_years.columns[4]], axis=1)

# %%
df_all_years = df_all_years.rename(columns=df_all_years.iloc[0])

# %%
df_all_years = df_all_years.drop(df_all_years[df_all_years['상품명']=='상품명'].index)

# %%
df_all_years
# Out:
#                      상품명         조사일  판매가격
# 1              샘표소면(1kg)  2016-06-03  3800
# 2              샘표소면(1kg)  2016-06-03  3800
# 3              샘표소면(1kg)  2016-06-03  3800
# 4              샘표소면(1kg)  2016-06-03  3800
# 5              샘표소면(1kg)  2016-06-03  3800
# ...                  ...         ...   ...
# 41057065  해피바스 내추럴24핸드크림  2021-05-28  8000
# 41057066  해피바스 내추럴24핸드크림  2021-05-28  8000
# 41057067  해피바스 내추럴24핸드크림  2021-05-28  8000
# 41057068  해피바스 내추럴24핸드크림  2021-05-28  8000
# 41057069  해피바스 내추럴24핸드크림  2021-05-28  8500
#
# [41057001 rows x 3 columns]

# %%
df_all_years["판매가격"] = pd.to_numeric(df_all_years["판매가격"], downcast="float")

# %%
df=df_all_years.groupby(['상품명','조사일']).mean()
df
# Out:
#                                         판매가격
# 상품명                  조사일
# 1964 정통 크림빵          2016-06-03  2073.825439
#                      2016-06-10  2072.847656
#                      2016-06-17  2122.278564
#                      2016-06-24  2137.232666
#                      2016-07-01  2176.818115
# ...                                      ...
# 후레쉬랩(25cm x 50m)(3M) 2021-04-30  3944.444336
#                      2021-05-07  3875.000000
#                      2021-05-14  3885.714355
#                      2021-05-21  3950.000000
#                      2021-05-28  3885.000000
#
# [103464 rows x 1 columns]

# %%
df2=df.unstack()

# %%
df2=df2['판매가격']

# %%
df3=df2.dropna()
df3
# Out:
# 조사일                        2016-06-03   2016-06-10   2016-06-17   2016-06-24  \
# 상품명
# 1964 정통 크림빵               2073.825439  2072.847656  2122.278564  2137.232666
# 3분 쇠고기 짜장                 1174.000000  1070.236206  1148.359375  1163.464600
# 3분 쇠고기 카레                 1168.132324  1068.988281  1146.770386  1167.176514
# 고소한국산콩두부(부침용)(대상)         3633.103516  3633.783691  3633.557129  3632.312988
# 곰표 다목적밀가루(1kg)            1385.308105  1384.476196  1384.075806  1382.535156
# 롯데 자일리톨 오리지날(87g)         3941.764648  3946.907959  3942.142822  3944.870117
# 맛있는 미역국                   1297.335938  1295.450928  1299.961182  1292.226562
# 맛있는오뚜기밥(6개입)              5641.285645  5742.523926  5701.421875  5616.507324
# 메로나(단품)                    506.780762   524.924744   529.732605   518.278076
# 백설 중력밀가루(1kg)             1441.105957  1441.605469  1441.788940  1440.322632
# 백설부침가루(1kg)               2245.961426  2248.697266  2176.781494  2161.000000
# ...

# %%
a=df3.columns
a
# Out:
# Index(['2016-06-03', '2016-06-10', '2016-06-17', '2016-06-24', '2016-07-01',
#        '2016-07-08', '2016-07-15', '2016-07-22', '2016-07-29', '2016-08-05',
#        ...
#        '2021-03-26', '2021-04-02', '2021-04-09', '2021-04-16', '2021-04-23',
#        '2021-04-30', '2021-05-07', '2021-05-14', '2021-05-21', '2021-05-28'],
#       dtype='object', name='조사일', length=245)

# %%
a=a.values.tolist()

# %%
a
# Out:
# ['2016-06-03',
#  '2016-06-10',
#  '2016-06-17',
#  '2016-06-24',
#  '2016-07-01',
#  '2016-07-08',
#  '2016-07-15',
#  '2016-07-22',
#  '2016-07-29',
#  '2016-08-05',
#  '2016-08-12',
#  '2016-08-19',
#  '2016-08-26',
#  '2016-09-02',
#  '2016-09-09',
#  '2016-09-23',
#  '2016-09-30',
#  '2016-10-07',
#  '2016-10-14',
#  '2016-10-21',
#  '2016-10-28',
#  '2016-11-04',
#  '2016-11-11',
#  '2016-11-18',
#  '2016-11-25',
#  '2016-12-02',
#  '2016-12-09',
#  '2016-12-16',
#  '2016-12-23',
#  '2016-12-30',
#  '2017-01-06',
#  '2017-01-13',
#  '2017-01-20',
#  '2017-02-03',
#  '2017-02-10',
#  '2017-02-17',
#  '2017-02-24',
#  '2017-03-03',
#  '2017-03-10',
#  '2017-03-17',
#  '2017-03-24',
#  '2017-03-31',
#  '2017-04-07',
#  '2017-04-14',
#  '2017-04-21',
#  '2017-04-28',
#  '2017-05-12',
#  '2017-05-19',
#  '2017-05-26',
#  '2017-06-02',
#  '2017-06-09',
#  '2017-06-16',
#  '2017-06-23',
#  '2017-06-30',
#  '2017-07-07',
#  '2017-07-14',
#  '2017-07-21',
#  '2017-07-28',
# ...

# %%
len(a)
# Out:
# 245

# %%
cd ../
# Out:
# C:\Users\mo135\2021projectdata

# %%
date= pd.read_csv('date.csv')
b=date.T
b
# Out:
#              0           1           2           3           4           5    \
# date  2016-06-03  2016-06-10  2016-06-17  2016-06-24  2016-07-01  2016-07-08
#
#              6           7           8           9    ...         251  \
# date  2016-07-15  2016-07-22  2016-07-29  2016-08-05  ...  2021-03-26
#
#              252         253         254         255         256         257  \
# date  2021-04-02  2021-04-09  2021-04-16  2021-04-23  2021-04-30  2021-05-07
#
#              258         259         260
# date  2021-05-14  2021-05-21  2021-05-28
#
# [1 rows x 261 columns]

# %%
b=b.values.flatten().tolist()
b
# Out:
# ['2016-06-03',
#  '2016-06-10',
#  '2016-06-17',
#  '2016-06-24',
#  '2016-07-01',
#  '2016-07-08',
#  '2016-07-15',
#  '2016-07-22',
#  '2016-07-29',
#  '2016-08-05',
#  '2016-08-12',
#  '2016-08-19',
#  '2016-08-26',
#  '2016-09-02',
#  '2016-09-09',
#  '2016-09-16',
#  '2016-09-23',
#  '2016-09-30',
#  '2016-10-07',
#  '2016-10-14',
#  '2016-10-21',
#  '2016-10-28',
#  '2016-11-04',
#  '2016-11-11',
#  '2016-11-18',
#  '2016-11-25',
#  '2016-12-02',
#  '2016-12-09',
#  '2016-12-16',
#  '2016-12-23',
#  '2016-12-30',
#  '2017-01-06',
#  '2017-01-13',
#  '2017-01-20',
#  '2017-01-27',
#  '2017-02-03',
#  '2017-02-10',
#  '2017-02-17',
#  '2017-02-24',
#  '2017-03-03',
#  '2017-03-10',
#  '2017-03-17',
#  '2017-03-24',
#  '2017-03-31',
#  '2017-04-07',
#  '2017-04-14',
#  '2017-04-21',
#  '2017-04-28',
#  '2017-05-05',
#  '2017-05-12',
#  '2017-05-19',
#  '2017-05-26',
#  '2017-06-02',
#  '2017-06-09',
#  '2017-06-16',
#  '2017-06-23',
#  '2017-06-30',
#  '2017-07-07',
# ...

# %%
len(b)
# Out:
# 261

# %%
same=[]
for i in b:
    if i not in a:
        same.append(i)

# %%
same
# Out:
# ['2016-09-16',
#  '2017-01-27',
#  '2017-05-05',
#  '2017-09-29',
#  '2017-10-06',
#  '2018-01-05',
#  '2018-02-16',
#  '2018-09-28',
#  '2019-02-08',
#  '2019-05-03',
#  '2019-06-07',
#  '2019-09-13',
#  '2020-01-03',
#  '2020-01-24',
#  '2020-10-02',
#  '2021-02-12']

# %%
for i in range(0, len(same)):
    df3[same[i]]=np.nan
# Out:
# C:\Users\mo135\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df3
# Out:
# 조사일                        2016-06-03   2016-06-10   2016-06-17   2016-06-24  \
# 상품명
# 1964 정통 크림빵               2073.825439  2072.847656  2122.278564  2137.232666
# 3분 쇠고기 짜장                 1174.000000  1070.236206  1148.359375  1163.464600
# 3분 쇠고기 카레                 1168.132324  1068.988281  1146.770386  1167.176514
# 고소한국산콩두부(부침용)(대상)         3633.103516  3633.783691  3633.557129  3632.312988
# 곰표 다목적밀가루(1kg)            1385.308105  1384.476196  1384.075806  1382.535156
# 롯데 자일리톨 오리지날(87g)         3941.764648  3946.907959  3942.142822  3944.870117
# 맛있는 미역국                   1297.335938  1295.450928  1299.961182  1292.226562
# 맛있는오뚜기밥(6개입)              5641.285645  5742.523926  5701.421875  5616.507324
# 메로나(단품)                    506.780762   524.924744   529.732605   518.278076
# 백설 중력밀가루(1kg)             1441.105957  1441.605469  1441.788940  1440.322632
# 백설부침가루(1kg)               2245.961426  2248.697266  2176.781494  2161.000000
# ...

# %%
df3=df3.T

# %%
df3_sort=df3.sort_index()
df3_sort
# Out:
# 상품명         1964 정통 크림빵    3분 쇠고기 짜장    3분 쇠고기 카레  고소한국산콩두부(부침용)(대상)  \
# 조사일
# 2016-06-03  2073.825439  1174.000000  1168.132324        3633.103516
# 2016-06-10  2072.847656  1070.236206  1068.988281        3633.783691
# 2016-06-17  2122.278564  1148.359375  1146.770386        3633.557129
# 2016-06-24  2137.232666  1163.464600  1167.176514        3632.312988
# 2016-07-01  2176.818115  1170.314941  1207.548096        3631.292480
# ...                 ...          ...          ...                ...
# 2021-04-30  2957.646973  1447.737061  1447.846191        3729.715820
# 2021-05-07  3275.324707  1459.565186  1458.052979        3719.252930
# 2021-05-14  3275.921143  1140.464355  1138.680176        3724.857178
# 2021-05-21  3275.649414  1143.554810  1141.193848        3729.715820
# 2021-05-28  3275.723633  1449.967896  1448.745972        3646.519043
#
# 상품명         곰표 다목적밀가루(1kg)  롯데 자일리톨 오리지날(87g)      맛있는 미역국  맛있는오뚜기밥(6개입)   \
# 조사일
# ...

# %%
df3_drop1=df3_sort.fillna(method='ffill')
#df2_drop1=df2_drop1.dropna(axis=1)
df3_drop1
# Out:
# 상품명         1964 정통 크림빵    3분 쇠고기 짜장    3분 쇠고기 카레  고소한국산콩두부(부침용)(대상)  \
# 조사일
# 2016-06-03  2073.825439  1174.000000  1168.132324        3633.103516
# 2016-06-10  2072.847656  1070.236206  1068.988281        3633.783691
# 2016-06-17  2122.278564  1148.359375  1146.770386        3633.557129
# 2016-06-24  2137.232666  1163.464600  1167.176514        3632.312988
# 2016-07-01  2176.818115  1170.314941  1207.548096        3631.292480
# ...                 ...          ...          ...                ...
# 2021-04-30  2957.646973  1447.737061  1447.846191        3729.715820
# 2021-05-07  3275.324707  1459.565186  1458.052979        3719.252930
# 2021-05-14  3275.921143  1140.464355  1138.680176        3724.857178
# 2021-05-21  3275.649414  1143.554810  1141.193848        3729.715820
# 2021-05-28  3275.723633  1449.967896  1448.745972        3646.519043
#
# 상품명         곰표 다목적밀가루(1kg)  롯데 자일리톨 오리지날(87g)      맛있는 미역국  맛있는오뚜기밥(6개입)   \
# 조사일
# ...

# %%
df3_drop2=df3_drop1.dropna(axis=1)
df3_drop2
# Out:
# 상품명         1964 정통 크림빵    3분 쇠고기 짜장    3분 쇠고기 카레  고소한국산콩두부(부침용)(대상)  \
# 조사일
# 2016-06-03  2073.825439  1174.000000  1168.132324        3633.103516
# 2016-06-10  2072.847656  1070.236206  1068.988281        3633.783691
# 2016-06-17  2122.278564  1148.359375  1146.770386        3633.557129
# 2016-06-24  2137.232666  1163.464600  1167.176514        3632.312988
# 2016-07-01  2176.818115  1170.314941  1207.548096        3631.292480
# ...                 ...          ...          ...                ...
# 2021-04-30  2957.646973  1447.737061  1447.846191        3729.715820
# 2021-05-07  3275.324707  1459.565186  1458.052979        3719.252930
# 2021-05-14  3275.921143  1140.464355  1138.680176        3724.857178
# 2021-05-21  3275.649414  1143.554810  1141.193848        3729.715820
# 2021-05-28  3275.723633  1449.967896  1448.745972        3646.519043
#
# 상품명         곰표 다목적밀가루(1kg)  롯데 자일리톨 오리지날(87g)      맛있는 미역국  맛있는오뚜기밥(6개입)   \
# 조사일
# ...

# %%
df3_drop2.to_csv('good_result2.csv',index=False,encoding='cp949')
